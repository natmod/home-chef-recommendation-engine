# %% [markdown]
# ## High Level Guide to This Project
#
# 1. Web Scraping and Getting the Data
#
#     a. Scrape the Home Chef website to get all the menu items and categories from current and future weeks
#
#     b. Manipulate an existing restaurant ratings dataset to generate some "user data".
#
# 2. Making Recommendations
#
#     a. Build the Recommendation Engine (Cross-Collaborative Filter). Tune Recommendations to minimize RMSE.
#
#     b. Make Predictions using the Engine

# %% [markdown]
# ## Part 1a: Web Scraping
#
# I need to generate a matrix of customers and menu items before performing the recommendation machine learning. For customers and ratings, I will generate some randomized data. For the menu items, I'll scrape them from the Home Chef Website for practice.

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.homechef.com/our-menu"
r = requests.get(url)
html_doc = r.text
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
#let's get links to all the other weeks of menu items available on the site
import re
weeks = [url]

for link in soup.find_all('a'):
    href = link.get('href')
    if re.match('/our-menus/', href) and not re.search('standard$', href):
        weeks.append('https://www.homechef.com' + href)
print(weeks)
# Out:
# ['https://www.homechef.com/our-menu', 'https://www.homechef.com/our-menus/29-may-2017', 'https://www.homechef.com/our-menus/05-jun-2017', 'https://www.homechef.com/our-menus/12-jun-2017', 'https://www.homechef.com/our-menus/19-jun-2017']

# %%
import time
meal_categs = {}

for url in weeks:
    time.sleep(1)
    
    r = requests.get(url)
    html_doc = r.text
    soup = BeautifulSoup(html_doc, 'html.parser')

    cards = soup.find_all(id='meal')
    for card in cards:
        values = []
        meal = card.h2.text
    
        categs = card.find_all('li')
        for categ in categs:
            values.append(categ.span.text)
    
        icons = card.find_all('i')
        for icon in icons:
            values.append(icon['data-tooltip'])
    
        meal_categs[meal] = values
    
print(meal_categs)
# Out:
# {'Steak au Poivre': ['Milk', 'Carb-Conscious'], 'Baja Fish Tacos': ['Eggs', 'Fish', 'Wheat'], 'BBQ-Rubbed Crispy Chicken': ['Milk', 'Wheat', 'Soy'], 'Swiss Fondue Burger': ['Milk', 'Eggs', 'Wheat', 'Soy'], 'Shrimp with Tiger Sauce': ['Fish', 'Wheat', 'Soy', 'Shellfish', 'Calorie-Conscious'], 'Roasted Chicken with Patatas Bravas': ['Calorie-Conscious'], 'Jalapeño Popper-Stuffed Pork Tenderloin': ['Milk', 'Calorie-Conscious', 'Carb-Conscious'], 'Chicken Chopped Salad': ['Milk', 'Tree Nuts', 'Calorie-Conscious', 'Carb-Conscious'], 'Neapolitan Pizza Margherita': ['Milk', 'Eggs', 'Wheat', 'Calorie-Conscious', 'Vegetarian'], 'One-Skillet Lemon Orzo Risotto': ['Milk', 'Wheat', 'Tree Nuts', 'Vegetarian'], 'Teriyaki Veggie Bibimbap': ['Wheat', 'Soy', 'Calorie-Conscious', 'Vegetarian'], 'Mango Tango Smoothie ': ['Milk', 'Vegetarian'], 'Spring Fruit Basket': ['Vegetarian'], 'Steak Moutarde': ['Milk', 'Calorie-Conscious'], 'Pork Shumai Meatballs': ['Wheat', 'Soy', 'Calorie-Conscious'], 'Chicken Pot Pie Primavera': ['Eggs', 'Wheat'], 'Crispy Honey-Soy Barramundi': ['Eggs', 'Fish', 'Soy', 'Calorie-Conscious', 'Carb-Conscious'], 'Piedmont Chicken Breast': ['Milk', 'Tree Nuts', 'Calorie-Conscious', 'Carb-Conscious'], 'Italian Sausage Parma Rosa': ['Milk', 'Wheat'], 'BBQ Shrimp Pizza': ['Milk', 'Eggs', 'Wheat', 'Soy', 'Shellfish', 'Calorie-Conscious'], 'Pork Chop with Pine Nut & Parmesan Butter': ['Milk', 'Tree Nuts', 'Calorie-Conscious', 'Carb-Conscious'], 'Broccoli Parmesan Risotto': ['Milk', 'Calorie-Conscious', 'Vegetarian'], 'Sun-Dried Tomato Pesto Spaghetti': ['Milk', 'Wheat', 'Soy', 'Tree Nuts', 'Vegetarian'], 'Fuji Apple Salad with Everything Bagel Croutons': ['Wheat', 'Tree Nuts', 'Calorie-Conscious', 'Vegetarian'], 'Pineapple Powwow Smoothie': ['Milk', 'Vegetarian'], 'Seasonal Fruit Basket': ['Vegetarian'], 'Grilled Sirloin Steak Salad ': ['Milk', 'Eggs', 'Wheat'], 'Chicken Kiev': ['Milk', 'Eggs', 'Wheat', 'Calorie-Conscious', 'Carb-Conscious'], 'Steelhead Trout in Shallot-Butter Sauce': ['Milk', 'Fish', 'Calorie-Conscious'], 'Al Pastor Pork Tacos': ['Eggs', 'Wheat'], 'Korean Pork Medallions': ['Soy', 'Calorie-Conscious', 'Carb-Conscious'], 'Fiesta Chicken': ['Milk', 'Calorie-Conscious', 'Carb-Conscious'], 'Classic Veggie Lasagna ': ['Milk', 'Wheat', 'Vegetarian'], 'Tandoori-Rubbed Chicken': ['Milk', 'Calorie-Conscious', 'Carb-Conscious'], 'French Toast and Bacon Monte Cristo': ['Milk', 'Eggs', 'Wheat'], 'Coconut Jasmine Rice Bowl': ['Vegetarian'], 'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': ['Milk', 'Wheat', 'Calorie-Conscious', 'Vegetarian'], 'Strawberry Colada Smoothie': ['Milk', 'Vegetarian'], 'Filet Mignon with Balsamic Onion Marmalada': ['Milk', 'Calorie-Conscious'], 'Shrimp Scampi': ['Milk', 'Wheat', 'Soy', 'Shellfish'], 'Farmhouse Fried Chicken': ['Milk', 'Eggs', 'Wheat'], 'Healthy Takeout Mongolian Beef': ['Peanuts', 'Soy'], 'Chicken and Roasted Beet Salad': ['Milk', 'Tree Nuts', 'Calorie-Conscious', 'Carb-Conscious'], 'Thai Fish Curry': ['Fish', 'Soy', 'Calorie-Conscious'], 'Buffalo Turkey Meatball Salad': ['Milk', 'Eggs', 'Soy', 'Calorie-Conscious', 'Carb-Conscious'], 'French Mustard-Thyme Butter Pork Chop': ['Milk', 'Calorie-Conscious', 'Carb-Conscious'], 'Marsala Mushroom Gemelli Bake': ['Milk', 'Wheat', 'Vegetarian'], 'Chayote Squash Enchiladas Verdes': ['Milk', 'Wheat', 'Vegetarian'], 'Crispy Tofu with Chimichurri Aioli': ['Eggs', 'Soy', 'Calorie-Conscious', 'Vegetarian'], 'Chocolate Strawberry Coconut Smoothie': ['Milk', 'Vegetarian'], 'Sirloin Steak and Shishito Pepper Skewers': ['Milk', 'Soy'], 'Garlic-Studded Pork Tenderloin': ['Milk', 'Calorie-Conscious', 'Carb-Conscious'], 'Thai Turkey Lettuce Wraps': ['Wheat', 'Soy', 'Calorie-Conscious', 'Carb-Conscious'], 'Skinny Chicken Bruschetta': ['Milk', 'Tree Nuts', 'Calorie-Conscious', 'Carb-Conscious'], 'Argentine Shrimp Chimichurri': ['Milk', 'Shellfish', 'Calorie-Conscious'], 'Acapulco Beef Burger': ['Milk', 'Eggs', 'Wheat'], 'Chicken Risotto Casserole ...

# %%
#Create a set of categories from the dictionary values
categories = set()
for i in list(meal_categs.values()):
    for j in i:
        categories.add(j)
print(categories)
print(len(categories))
# Out:
# {'Milk', 'Eggs', 'Fish', 'Vegetarian', 'Peanuts', 'Shellfish', 'Soy', 'Calorie-Conscious', 'Wheat', 'Tree Nuts', 'Carb-Conscious'}
# 11

# %%
#Create a set of menu items from the dictionary keys
meals = set(meal_categs.keys())
print(list(meals)[:5])
print(len(meals))
# Out:
# ['Spring Fruit Basket', 'Pineapple Powwow Smoothie', 'Swiss Fondue Burger', 'Chayote Squash Enchiladas Verdes', 'Filet Mignon with Balsamic Onion Marmalada']
# 62

# %%
#Next we need to make a table that shows what categories
#the menu item falls into.
import pandas as pd
import numpy as np

m = len(meals)
n = len(categories)

df_menu = pd.DataFrame(data=np.zeros((m,n)), columns=categories, index=meals)
df_menu.head()
# Out:
#                                             Milk  Eggs  Fish  Vegetarian  \
# Spring Fruit Basket                          0.0   0.0   0.0         0.0
# Pineapple Powwow Smoothie                    0.0   0.0   0.0         0.0
# Swiss Fondue Burger                          0.0   0.0   0.0         0.0
# Chayote Squash Enchiladas Verdes             0.0   0.0   0.0         0.0
# Filet Mignon with Balsamic Onion Marmalada   0.0   0.0   0.0         0.0
#
#                                             Peanuts  Shellfish  Soy  \
# Spring Fruit Basket                             0.0        0.0  0.0
# Pineapple Powwow Smoothie                       0.0        0.0  0.0
# Swiss Fondue Burger                             0.0        0.0  0.0
# Chayote Squash Enchiladas Verdes                0.0        0.0  0.0
# Filet Mignon with Balsamic Onion Marmalada      0.0        0.0  0.0
#
#                                             Calorie-Conscious  Wheat  \
# Spring Fruit Basket                                       0.0    0.0
# Pineapple Powwow Smoothie                                 0.0    0.0
# Swiss Fondue Burger                                       0.0    0.0
# Chayote Squash Enchiladas Verdes                          0.0    0.0
# Filet Mignon with Balsamic Onion Marmalada                0.0    0.0
#
#                                             Tree Nuts  Carb-Conscious
# Spring Fruit Basket                               0.0             0.0
# Pineapple Powwow Smoothie                         0.0             0.0
# Swiss Fondue Burger                               0.0             0.0
# Chayote Squash Enchiladas Verdes                  0.0             0.0
# Filet Mignon with Balsamic Onion Marmalada        0.0             0.0

# %%
#Now let's populate the table based on the dictionary

for meal in meals:
    for categ in meal_categs[meal]:
        df_menu.ix[meal][categ] = 1
df_menu.head()
# Out:
#                                             Milk  Eggs  Fish  Vegetarian  \
# Spring Fruit Basket                          0.0   0.0   0.0         1.0
# Pineapple Powwow Smoothie                    1.0   0.0   0.0         1.0
# Swiss Fondue Burger                          1.0   1.0   0.0         0.0
# Chayote Squash Enchiladas Verdes             1.0   0.0   0.0         1.0
# Filet Mignon with Balsamic Onion Marmalada   1.0   0.0   0.0         0.0
#
#                                             Peanuts  Shellfish  Soy  \
# Spring Fruit Basket                             0.0        0.0  0.0
# Pineapple Powwow Smoothie                       0.0        0.0  0.0
# Swiss Fondue Burger                             0.0        0.0  1.0
# Chayote Squash Enchiladas Verdes                0.0        0.0  0.0
# Filet Mignon with Balsamic Onion Marmalada      0.0        0.0  0.0
#
#                                             Calorie-Conscious  Wheat  \
# Spring Fruit Basket                                       0.0    0.0
# Pineapple Powwow Smoothie                                 0.0    0.0
# Swiss Fondue Burger                                       0.0    1.0
# Chayote Squash Enchiladas Verdes                          0.0    1.0
# Filet Mignon with Balsamic Onion Marmalada                1.0    0.0
#
#                                             Tree Nuts  Carb-Conscious
# Spring Fruit Basket                               0.0             0.0
# Pineapple Powwow Smoothie                         0.0             0.0
# Swiss Fondue Burger                               0.0             0.0
# Chayote Squash Enchiladas Verdes                  0.0             0.0
# Filet Mignon with Balsamic Onion Marmalada        0.0             0.0

# %% [markdown]
# The table above could be used for Content-based filtering. However, for this exercise I'll be using Collaborative filtering (User-based). If I were to create a method for content-based filtering, I would want to create some more descriptive columns for each dish. These additional columns could be based on ingredients, region, or cooking methods.

# %% [markdown]
# ## Part 1b: Generating Random User Meal Ratings Data

# %% [markdown]
# Since I don't have access to the actual Home Chef Ratings, I found another ratings data source online. This dataset hold ratings for restaurants, so somewhat similar to what we are looking for. Since the ratings are broken out into three categories, I will do some quick algebra to convert to single rating on a 5-star scale (Home Chef rating scale).

# %%
#we need a new table that will hold user_ids and reviews of menu items
d = pd.read_csv('RCData/rating_final.csv')
d['r'] = np.round((d.rating + d.food_rating + d.service_rating)*5/6)
d.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating    r
# 0  U1077   135085       2            2               2  5.0
# 1  U1077   135038       2            2               1  4.0
# 2  U1077   132825       2            2               2  5.0
# 3  U1077   135060       1            2               2  4.0
# 4  U1068   135104       1            1               2  3.0

# %% [markdown]
# Checking the distribution of reviews. Looks ok.

# %%
d.r.value_counts().sort_index()
# Out:
# 0.0    193
# 1.0     43
# 2.0    312
# 3.0    178
# 4.0    142
# 5.0    293
# Name: r, dtype: int64

# %% [markdown]
# I'll just grab the restaurants with the most reviews up to the number of meals on the available Home Chef menus (62 at the time I did this).

# %%
top_places = d.groupby('placeID').size().sort_values(ascending=False).index[:len(meals)]

# %% [markdown]
# Next I'll take just those top restaurants and the users that reviewed them. I'll put them into a pandas dataframe as below.

# %%
df_ratings = d[d.placeID.isin(top_places)]
df_ratings = df_ratings.pivot_table(values='r', columns='placeID', index='userID')
df_ratings.columns = meals
df_ratings.head()
# Out:
#         Spring Fruit Basket  Pineapple Powwow Smoothie  Swiss Fondue Burger  \
# userID
# U1001                   NaN                        NaN                  NaN
# U1002                   NaN                        NaN                  NaN
# U1003                   NaN                        4.0                  NaN
# U1004                   NaN                        NaN                  NaN
# U1005                   NaN                        NaN                  NaN
#
#         Chayote Squash Enchiladas Verdes  \
# userID
# U1001                                NaN
# U1002                                NaN
# U1003                                NaN
# U1004                                NaN
# U1005                                NaN
#
#         Filet Mignon with Balsamic Onion Marmalada  \
# userID
# U1001                                          NaN
# U1002                                          NaN
# U1003                                          NaN
# U1004                                          NaN
# U1005                                          NaN
#
#         Strawberry Cheesecake Smoothie  Teriyaki Veggie Bibimbap  \
# userID
# U1001                              NaN                       NaN
# U1002                              NaN                       NaN
# U1003                              5.0                       NaN
# U1004                              NaN                       NaN
# U1005                              NaN                       NaN
#
#         BBQ-Rubbed Crispy Chicken  Steelhead Trout in Shallot-Butter Sauce  \
# userID
# U1001                         4.0                                      2.0
# U1002                         3.0                                      NaN
# U1003                         4.0                                      NaN
# U1004                         NaN                                      NaN
# U1005                         NaN                                      2.0
#
#         Fiesta Chicken            ...              \
# userID                            ...
# U1001              NaN            ...
# U1002              NaN            ...
# U1003              NaN            ...
# U1004              NaN            ...
# U1005              NaN            ...
#
#         Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad  \
# userID
# U1001                                                 NaN
# U1002                                                 NaN
# U1003                                                 5.0
# U1004                                                 NaN
# U1005                                                 NaN
#
#         Steak au Poivre  Piedmont Chicken Breast  \
# userID
# U1001               NaN                      NaN
# U1002               NaN                      NaN
# U1003               NaN                      5.0
# U1004               NaN                      NaN
# U1005               4.0                      NaN
#
#         One-Skillet Lemon Orzo Risotto  Classic Veggie Lasagna   \
# userID
# U1001                              NaN                      NaN
# U1002                              NaN                      NaN
# U1003                              NaN                      NaN
# U1004                              NaN                      NaN
# U1005                              NaN                      NaN
#
#         Acapulco Beef Burger  Garlic-Studded Pork Tenderloin  \
# userID
# U1001                    2.0                             NaN
# U1002                    2.0                             NaN
# U1003                    NaN                             NaN
# U1004                    NaN                             NaN
# U1005                    NaN                             NaN
#
#         Pork Chop with Pine Nut & Parmesan Butter  \
# userID
# U1001                                         NaN
# U1002                                         NaN
# U1003                                         NaN
# U1004                                         NaN
# U1005                                         NaN
#
#         Chicken and Roasted Beet Salad  Coconut Jasmine Rice Bowl
# userID
# U1001                              NaN                        NaN
# U1002                              2.0                        NaN
# U1003                              NaN                        NaN
# U1004                              5.0                        NaN
# U1005                              NaN                        NaN
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Part 2a: Cross Collaborative Filtering, Tuning the Recommendation Engine

# %% [markdown]
# Now with the data ready, it's time to perform the recommendation prediction. There are several Python packages for doing this, but I'll build some functions by hand to do the work for the purposes of this project.

# %% [markdown]
# First I'll melt (unpivot) the data and get rid of NaN values to make it easier to manipulate

# %%
df = df_ratings.reset_index()
df = pd.melt(df, id_vars=['userID'], var_name=['meal'])
df = df[df.value.notnull()]
df.rename(columns={'value': 'rating'}, inplace=True)
df.head()
# Out:
#    userID                 meal  rating
# 5   U1006  Spring Fruit Basket     2.0
# 6   U1007  Spring Fruit Basket     2.0
# 11  U1013  Spring Fruit Basket     2.0
# 29  U1033  Spring Fruit Basket     1.0
# 40  U1046  Spring Fruit Basket     2.0

# %% [markdown]
# Here's a helper function to split the data into training and test sets.

# %%
def assign_to_set(df):
    sampled_ids = np.random.choice(df.index,
                                   size=np.int64(np.ceil(df.index.size * 0.2)),
                                   replace=False)
    df.ix[sampled_ids, 'for_testing'] = True
    return df

df['for_testing'] = False
grouped = df.groupby('userID', group_keys=False).apply(assign_to_set)
df_train = df[grouped.for_testing == False]
df_test = df[grouped.for_testing == True]
print (df.shape)
print (df_train.shape)
print (df_test.shape)
assert (len(df_train.index & df_test.index) == 0)
# Out:
# (834, 4)
# (611, 4)
# (223, 4)

# %% [markdown]
# We'll also need evaluation metrics:

# %%
def compute_rmse(y_pred, y_true):
    """ Compute Root Mean Squared Error. """
    
    return np.sqrt(np.mean(np.power(y_pred - y_true, 2)))

# %%
def evaluate(estimate_f):
    """ RMSE-based predictive performance evaluation with pandas. """
    
    ids_to_estimate = zip(df_test.userID, df_test.meal)
    estimated = np.array([estimate_f(u,m) for (u,m) in ids_to_estimate])
    real = df_test.rating.values
    return compute_rmse(estimated, real)

# %% [markdown]
# I'll check the evaluation function by just guessing 3 for every meal.

# %%
def my_estimate_function(userID, meal):
    return 3

# %%
print ('RMSE for my estimate function: %s' % evaluate(my_estimate_function))
# Out:
# RMSE for my estimate function: 1.73980051431

# %% [markdown]
# Next I'll create some different similarity functions to try:

# %%
def euclidean(s1, s2):
    """Take two pd.Series objects and return their euclidean 'similarity'."""
    diff = s1 - s2
    return 1 / (1 + np.sqrt(np.sum(diff ** 2)))

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %% [markdown]
# Next, create a Class for the collaborative filtering recommender:

# %%
class CollabPearsonReco:
    """ Collaborative filtering using a custom sim(u,u'). """

    def learn(self):
        """ Prepare datastructures for estimation. """
        
        self.all_user_profiles = df.pivot_table('rating', index='meal', columns='userID')

    def estimate(self, userID, meal):
        """ Ratings weighted by correlation similarity. """
        
        user_condition = df_train.userID != userID
        meal_condition = df_train.meal == meal
        ratings_by_others = df_train.loc[user_condition & meal_condition]
        if ratings_by_others.empty: 
            return 3.0
        
        ratings_by_others.set_index('userID', inplace=True)
        their_ids = ratings_by_others.index
        their_ratings = ratings_by_others.rating
        their_profiles = self.all_user_profiles[their_ids]
        user_profile = self.all_user_profiles[userID]
        sims = their_profiles.apply(lambda profile: pearson(profile, user_profile), axis=0)
        ratings_sims = pd.DataFrame({'sim': sims, 'rating': their_ratings})
        ratings_sims = ratings_sims[ratings_sims.sim > 0]
        if ratings_sims.empty:
            return their_ratings.mean()
        else:
            return np.average(ratings_sims.rating, weights=ratings_sims.sim)
        
reco = CollabPearsonReco()
reco.learn()
print ('RMSE for CollabPearsonReco: %s' % evaluate(reco.estimate))
# Out:
# /Users/nate/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:5: RuntimeWarning: invalid value encountered in double_scalars
# RMSE for CollabPearsonReco: 1.64673677073

# %%
class CollabEuclidReco:
    """ Collaborative filtering using a custom sim(u,u'). """

    def learn(self):
        """ Prepare datastructures for estimation. """
        
        self.all_user_profiles = df.pivot_table('rating', index='meal', columns='userID')

    def estimate(self, userID, meal):
        """ Ratings weighted by correlation similarity. """
        
        user_condition = df_train.userID != userID
        meal_condition = df_train.meal == meal
        ratings_by_others = df_train.loc[user_condition & meal_condition]
        if ratings_by_others.empty: 
            return 3.0
        
        ratings_by_others.set_index('userID', inplace=True)
        their_ids = ratings_by_others.index
        their_ratings = ratings_by_others.rating
        their_profiles = self.all_user_profiles[their_ids]
        user_profile = self.all_user_profiles[userID]
        sims = their_profiles.apply(lambda profile: euclidean(profile, user_profile), axis=0)
        ratings_sims = pd.DataFrame({'sim': sims, 'rating': their_ratings})
        ratings_sims = ratings_sims[ratings_sims.sim > 0]
        if ratings_sims.empty:
            return their_ratings.mean()
        else:
            return np.average(ratings_sims.rating, weights=ratings_sims.sim)
    
    def recommend(self, userID, n=5):
        """ Recommend the top n meals for this user. """
        
        other_ratings = df[df.userID != userID]
        ratings_by_others.set_index('userID', inplace=True)
        their_ids = ratings_by_others.index
        sims = their_profiles.apply(lambda profile: euclidean(profile, user_profile), axis=0)
        
reco = CollabEuclidReco()
reco.learn()
print ('RMSE for CollabPearsonReco: %s' % evaluate(reco.estimate))
# Out:
# RMSE for CollabPearsonReco: 1.34188924004

# %% [markdown]
# Euclidean similarity had a better RMSE than Pearson similartiy (1.34 vs 1.64 respectively), so I'll use the Euclidean function going forward. With a larger dataset and preferably real empirical data, I would tune the algorithm to get the lowest RMSE.

# %% [markdown]
# ## Part 2b: Using the Recommendation Engine to Make Predictions

# %% [markdown]
# Next, I'll look at a random user to see how well the model can predict something the user has already rated. In this case, we will look at the prediction for the "Buffalo Turkey Meatball Salad".

# %%
df[df.userID=='U1025']
# Out:
#      userID                                             meal  rating  \
# 884   U1025                        BBQ-Rubbed Crispy Chicken     0.0
# 1007  U1025          Steelhead Trout in Shallot-Butter Sauce     5.0
# 2852  U1025                    Buffalo Turkey Meatball Salad     2.0
# 4082  U1025            Chocolate Strawberry Coconut Smoothie     2.0
# 5558  U1025                          Tandoori-Rubbed Chicken     5.0
# 6173  U1025  Fuji Apple Salad with Everything Bagel Croutons     5.0
#
#      for_testing
# 884        False
# 1007       False
# 2852       False
# 4082       False
# 5558       False
# 6173       False

# %%
print("Estimated Rating: ", reco.estimate(userID='U1025',meal='Buffalo Turkey Meatball Salad'))
print("Actual Rating: ", df[(df.userID=='U1025') & (df.meal=='Buffalo Turkey Meatball Salad')].rating.item())
# Out:
# Estimated Rating:  2.74772017217
# Actual Rating:  2.0

# %% [markdown]
# Pretty good. You can see for this case, the model was able to predict the user's actual rating fairly closely. Although this is only one case of many, we know we are on the right track.

# %% [markdown]
# Now I'll take a user and provide the top 5 recommendations for the next meal she should try. For this case, I'm going to convert the dataframe into a dictionary for easier manipulation.

# %%
from pandas import compat

rating_dict = df.pivot_table('rating', index='meal', columns='userID',)
def to_dict_dropna(data):
  return dict((k, v.dropna().to_dict()) for k, v in compat.iteritems(data))
rating_dict = to_dict_dropna(rating_dict)
rating_dict
# Out:
# {'U1001': {'Acapulco Beef Burger': 2.0,
#   'BBQ-Rubbed Crispy Chicken': 4.0,
#   'Crispy Honey-Soy Barramundi': 2.0,
#   'Korean Pork Medallions': 5.0,
#   'New England-Style Fish Cakes': 2.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 2.0,
#   'Thai Turkey Lettuce Wraps': 3.0},
#  'U1002': {'Acapulco Beef Burger': 2.0,
#   'Asparagus Panzanella Primavera': 3.0,
#   'BBQ Shrimp Pizza': 2.0,
#   'BBQ-Rubbed Crispy Chicken': 3.0,
#   'Chicken Pot Pie Primavera': 3.0,
#   'Chicken Risotto Casserole': 2.0,
#   'Chicken and Roasted Beet Salad': 2.0,
#   'Roasted Chicken with Patatas Bravas': 3.0,
#   'Skinny Chicken Bruschetta': 5.0},
#  'U1003': {'BBQ Shrimp Pizza': 2.0,
#   'BBQ-Rubbed Crispy Chicken': 4.0,
#   'Chicken Pot Pie Primavera': 5.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 5.0,
#   'Piedmont Chicken Breast': 5.0,
#   'Pineapple Powwow Smoothie': 4.0,
#   'Skinny Chicken Bruschetta': 4.0,
#   'Strawberry Cheesecake Smoothie': 5.0,
#   'Tandoori-Rubbed Chicken': 0.0},
#  'U1004': {'Buffalo Turkey Meatball Salad': 5.0,
#   'Chicken Kiev': 5.0,
#   'Chicken and Roasted Beet Salad': 5.0,
#   'Pork Shumai Meatballs': 5.0,
#   'Roasted Chicken with Patatas Bravas': 4.0,
#   'Seasonal Fruit Basket': 2.0},
#  'U1005': {'BBQ Shrimp Pizza': 2.0,
#   'Baja Fish Tacos': 4.0,
#   'Chicken Kiev': 4.0,
#   'French Mustard-Thyme Butter Pork Chop': 3.0,
#   'Marsala Mushroom Gemelli Bake': 3.0,
#   'Steak au Poivre': 4.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 2.0,
#   'Sun-Dried Tomato Pesto Spaghetti': 2.0,
#   'Thai Fish Curry': 3.0},
#  'U1006': {'BBQ-Rubbed Crispy Chicken': 2.0,
#   'Farmhouse Fried Chicken': 5.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 3.0,
#   'Grilled Sirloin Steak Salad ': 5.0,
#   'Piedmont Chicken Breast': 2.0,
#   'Pork Shumai Meatballs': 2.0,
#   'Spring Fruit Basket': 2.0,
#   'Strawberry Colada Smoothie': 3.0},
#  'U1007': {'Acapulco Beef Burger': 2.0,
#   'Chicken Kiev': 2.0,
#   'Coconut Jasmine Rice Bowl': 2.0,
#   'French Mustard-Thyme Butter Pork Chop': 3.0,
#   'Garlic-Studded Pork Tenderloin': 0.0,
#   'Korean Pork Medallions': 2.0,
#   'Neapolitan Pizza Margherita': 2.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 3.0,
#   'Spring Fruit Basket': 2.0},
#  'U1008': {'Al Pastor Pork Tacos': 2.0,
#   'Coconut Jasmine Rice Bowl': 2.0,
#   'Shrimp with Tiger Sauce': 2.0},
#  'U1009': {'BBQ-Rubbed Crispy Chicken': 2.0,
#   'Chicken Pot Pie Primavera': 3.0,
#   'Chicken Risotto Casserole': 2.0,
#   'Fiesta Chicken': 4.0,
#   'Jalapeño Popper-Stuffed Pork Tenderloin': 0.0,
#   'Neapolitan Pizza Margherita': 5.0,
#   'Piedmont Chicken Breast': 4.0,
#   'Seasonal Fruit Basket': 2.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 3.0,
#   'Skinny Chicken Bruschetta': 4.0,
#   'Strawberry Cheesecake Smoothie': 3.0},
#  'U1010': {'Baja Fish Tacos': 5.0,
#   'Chocolate Strawberry Coconut Smoothie': 2.0,
#   'Crispy Tofu with Chimichurri Aioli': 2.0,
#   'Healthy Takeout Mongolian Beef': 2.0,
#   'Piedmont Chicken Breast': 0.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 1.0,
#   'Steak au Poivre': 4.0,
#   'Tandoori-Rubbed Chicken': 2.0},
#  'U1012': {'Chicken Chopped Salad': 5.0, 'Steak Moutarde': 5.0},
#  'U1013': {'Acapulco Beef Burger': 2.0,
#   'Asparagus Panzanella Primavera': 4.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 4.0,
#   'Grilled Sirloin Steak Salad ': 4.0,
#   'Italian Sausage Parma Rosa': 3.0,
#   'Piedmont Chicken Breast': 2.0,
#   'Seasonal Fruit Basket': 2.0,
#   'Shrimp Scampi': 5.0,
#   'Spring Fruit Basket': 2.0,
#   'Steak au Poivre': 2.0},
#  'U1014': {'Argentine Shrimp Chimichurri': 5.0,
#   'Baja Fish Tacos': 2.0,
#   'Classic Veggie Lasagna ': 0.0,
#   'French Mustard-Thyme Butter Pork Chop': 2.0,
#   'Marsala Mushroom Gemelli Bake': 4.0,
#   'One-Skillet Lemon Orzo Risotto': 3.0,
#   'Shrimp with Tiger Sauce': 2.0,
#   'Steak au Poivre': 3.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 4.0,
#   'Sun-Dried Tomato Pesto Spaghetti': 1.0,
#   'Thai Fish Curry': 5.0},
#  'U1015': {'Al Pastor Pork Tacos': 2.0,
#   'Fuji Apple Salad with Everything Bagel Croutons': 0.0},
#  'U1016': {'Acapulco Beef Burger': 3.0,
#   'Baja Fish Tacos': 4.0,
#   'Broccoli Parmesan Risotto': 5.0,
#   'Chicken Kiev': 5.0,
#   'Chicken Risotto Casserole': 5.0,
#   'Chicken and Roasted Beet Salad': 5.0,
#   'Fiesta Chicken': 5.0,
#   'Marsala Mushroom Gemelli Bake': 5.0,
#   'New England-Style Fish Cakes': 5.0,
#   'Roasted Chicken with Patatas Bravas': 5.0,
#   'Seasonal Fruit Basket': 5.0,
#   'Skinny Chicken Bruschetta': 5.0,
#   'Thai Turkey Lettuce Wraps': 3.0},
#  'U1017': {'Teriyaki Veggie Bibimbap': 2.0},
#  'U1018': {'Chicken Kiev': 2.0,
#   'Classic Veggie Lasagna ': 5.0,
#   'Coconut Jasmine Rice Bowl': 2.0,
#   'French Mustard-Thyme Butter Pork Chop': 2.0,
#   'Korean Pork Medallions': 2.0,
#   'Marsala Mushroom Gemelli Bake': 2.0,
#   'One-Skillet Lemon Orzo Risotto': 2.0,
#   'Roasted Chicken with Patatas Bravas': 1.0,
#   'Shrimp with Tiger Sauce': 2.0,
#   'Sun-Dried Tomato Pesto Spaghetti': 0.0},
#  'U1019': {'Asparagus Panzanella Primavera': 0.0,
#   'Broccoli Parmesan Risotto': 0.0,
#   'Fiesta Chicken': 0.0,
#   'Garlic-Studded Pork Tenderloin': 0.0,
#   'Neapolitan Pizza Margherita': 0.0,
#   'Piedmont Chicken Breast': 0.0,
#   'Roasted Chicken with Patatas Bravas': 0.0,
#   'Steak au Poivre': 0.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 0.0},
#  'U1020': {'Chicken Chopped Salad': 2.0, 'Teriyaki Veggie Bibimbap': 5.0},
#  'U1021': {'Filet Mignon with Balsamic Onion Marmalada': 4.0},
#  'U1022': {'Chicken Kiev': 3.0,
#   'Chicken Risotto Casserole': 5.0,
#   'French Mustard-Thyme Butter Pork Chop': 5.0,
#   'Jalapeño Popper-Stuffed Pork Tenderloin': 4.0,
#   'Korean Pork Medallions': 0.0,
#   'Neapolitan Pizza Margherita': 4.0,
#   'New England-Style Fish Cakes': 3.0,
#   'One-Skillet Lemon Orzo Risotto': 2.0,
#   'Roasted Chicken with Patatas Bravas': 3.0,
#   'Seasonal Fruit Basket': 3.0,
#   'Thai Turkey Lettuce Wraps': 3.0},
#  'U1023': {'Chayote Squash Enchiladas Verdes': 5.0,
#   'Filet Mignon with Balsamic Onion Marmalada': 0.0},
#  'U1024': {'BBQ Shrimp Pizza': 2.0,
#   'BBQ-Rubbed Crispy Chicken': 2.0,
#   'Baja Fish Tacos': 3.0,
#   'Buffalo Turkey Meatball Salad': 2.0,
#   'Chicken Kiev': 5.0,
#   'Chicken and Roasted Beet Salad': 2.0,
#   'Crispy Honey-Soy Barramundi': 5.0,
#   'Fiesta Chicken': 2.0,
#   'Mango Tango Smoothie ': 2.0,
#   'Neapolitan Pizza Margherita': 2.0,
#   'New England-Style Fish Cakes': 3.0,
#   'Seasonal Fruit Basket': 2.0,
#   'Strawberry Colada Smoothie': 2.0,
#   'Thai Turkey Lettuce Wraps': 2.0},
#  'U1025': {'BBQ-Rubbed Crispy Chicken': 0.0,
#   'Buffalo Turkey Meatball Salad': 2.0,
#   'Chocolate Strawberry Coconut Smoothie': 2.0,
#   'Fuji Apple Salad with Everything Bagel Croutons': 5.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 5.0,
#   'Tandoori-Rubbed Chicken': 5.0},
#  'U1027': {'Acapulco Beef Burger': 2.0,
#   'Asparagus Panzanella Primavera': 2.0,
#   'Baja Fish Tacos': 2.0,
#   'Chicken Risotto Casserole': 2.0,
#   'Fontina and Caramelized Onion Flatbread': 2.0,
#   'Grilled Sirloin Steak Salad ': 2.0,
#   'Marsala Mushroom Gemelli Bake': 0.0,
#   'Roasted Chicken with Patatas Bravas': 2.0,
#   'Shrimp Scampi': 2.0},
#  'U1028': {'Chayote Squash Enchiladas Verdes': 2.0,
#   'Filet Mignon with Balsamic Onion Marmalada': 2.0,
#   'Pork Chop with Pine Nut & Parmesan Butter': 1.0,
#   'Swiss Fondue Burger': 2.0},
#  'U1029': {'Acapulco Beef Burger': 2.0,
#   'Asparagus Panzanella Primavera': 2.0,
#   'BBQ-Rubbed Crispy Chicken': 2.0,
#   'Chicken Pot Pie Primavera': 3.0,
#   'Chocolate Strawberry Coconut Smoothie': 2.0,
#   'Fiesta Chicken': 1.0,
#   'Skinny Chicken Bruschetta': 2.0,
#   'Strawberry Cheesecake Smoothie': 0.0},
#  'U1030': {'Chicken Chopped Salad': 0.0, 'Steak Moutarde': 5.0},
#  'U1032': {'Acapulco Beef Burger': 2.0,
#   'Baja Fish Tacos': 1.0,
#   'Broccoli Parmesan Risotto': 2.0,
#   'Chicken Kiev': 0.0,
#   'Fiesta Chicken': 2.0,
#   'Fontina and Caramelized Onion Flatbread': 2.0,
#   'Neapolitan Pizza Margherita': 2.0,
#   'Piedmont Chicken Breast': 3.0,
#   'Seasonal Fruit Basket': 2.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 2.0},
#  'U1033': {'Acapulco Beef Burger': 5.0,
#   'Asparagus Panzanella Primavera': 3.0,
#   'Basil-Pecorino Campanelle': 3.0,
#   'Buffalo Turkey Meatball Salad': 3.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 2.0,
#   'Healthy Takeout Mongolian Beef': 2.0,
#   'Neapolitan Pizza Margherita': 2.0,
#   'New England-Style Fish Cakes': 4.0,
#   'Shrimp Scampi': 2.0,
#   'Spring Fruit Basket': 1.0,
#   'Strawberry Colada Smoothie': 3.0},
#  'U1034': {'Garlic-Studded Pork Tenderloin': 2.0,
#   'Pineapple Powwow Smoothie': 2.0},
#  'U1035': {'Chicken Chopped Salad': 4.0, 'Steak Moutarde': 5.0},
#  'U1036': {'Acapulco Beef Burger': 5.0,
#   'BBQ-Rubbed Crispy Chicken': 5.0,
#   'Baja Fish Tacos': 5.0,
#   'Chicken Pot Pie Primavera': 5.0,
#   'Chicken Risotto Casserole': 5.0,
#   'Fiesta Chicken': 4.0,
#   'Healthy Takeout Mongolian Beef': 0.0,
#   'Korean Pork Medallions': 5.0,
#   'New England-Style Fish Cakes': 5.0,
#   'Piedmont Chicken Breast': 5.0,
#   'Strawberry Cheesecake Smoothie': 5.0,
#   'Tandoori-Rubbed Chicken': 4.0},
#  'U1037': {'Al Pastor Pork Tacos': 3.0,
#   'Argentine Shrimp Chimichurri': 0.0,
#   'Classic Veggie Lasagna ': 0.0,
#   'Coconut Jasmine Rice Bowl': 5.0,
#   'Fuji Apple Salad with Everything Bagel Croutons': 1.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 5.0},
#  'U1038': {'Broccoli Parmesan Risotto': 2.0, 'Skinny Chicken Bruschetta': 5.0},
#  'U1041': {'French Toast and Bacon Monte Cristo': 5.0,
#   'Teriyaki Veggie Bibimbap': 4.0},
#  'U1042': {'Chicken Chopped Salad': 5.0,
#   'French Toast and Bacon Monte Cristo': 2.0,
#   'Steak Moutarde': 5.0,
#   'Teriyaki Veggie Bibimbap': 4.0},
#  'U1043': {'Swiss Fondue Burger': 2.0},
#  'U1044': {'Steak Moutarde': 5.0, 'Teriyaki Veggie Bibimbap': 5.0},
#  'U1045': {'Acapulco Beef Burger': 5.0,
#   'BBQ Shrimp Pizza': 3.0,
#   'BBQ-Rubbed Crispy Chicken': 3.0,
#   'Broccoli Parmesan Risotto': 4.0,
#   'Chicken Kiev': 0.0,
#   'Chicken Risotto Casserole': 4.0,
#   'Fiesta Chicken': 2.0,
#   'Seasonal Fruit Basket': 5.0,
#   'Tandoori-Rubbed Chicken': 0.0,
#   'Thai Turkey Lettuce Wraps': 5.0},
#  'U1046': {'Acapulco Beef Burger': 3.0,
#   'Asparagus Panzanella Primavera': 4.0,
#   'Farmhouse Fried Chicken': 2.0,
#   'Healthy Takeout Mongolian Beef': 5.0,
#   'Shrimp Scampi': 3.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 4.0,
#   'Spring Fruit Basket': 2.0},
#  'U1047': {'Grilled Sirloin Steak Salad ': 0.0},
#  'U1048': {'Farmhouse Fried Chicken': 5.0,
#   'Healthy Takeout Mongolian Beef': 3.0,
#   'Pineapple Powwow Smoothie': 5.0},
#  'U1049': {'Acapulco Beef Burger': 0.0,
#   'Asparagus Panzanella Primavera': 0.0,
#   'BBQ Shrimp Pizza': 0.0,
#   'BBQ-Rubbed Crispy Chicken': 0.0,
#   'Baja Fish Tacos': 0.0,
#   'Chicken Kiev': 0.0,
#   'Chicken Risotto Casserole': 0.0,
#   'Skinny Chicken Bruschetta': 0.0,
#   'Thai Turkey Lettuce Wraps': 0.0},
#  'U1050': {'Filet Mignon with Balsamic Onion Marmalada': 2.0,
#   'Swiss Fondue Burger': 2.0},
#  'U1051': {'Chicken Chopped Salad': 3.0, 'Teriyaki Veggie Bibimbap': 3.0},
#  'U1053': {'BBQ-Rubbed Crispy Chicken': 2.0,
#   'Baja Fish Tacos': 4.0,
#   'Chicken Kiev': 4.0,
#   'Chocolate Strawberry Coconut Smoothie': 5.0,
#   'Crispy Tofu with Chimichurri Aioli': 3.0,
#   'Jalapeño Popper-Stuffed Pork Tenderloin': 4.0,
#   'Korean Pork Medallions': 4.0,
#   'Neapolitan Pizza Margherita': 4.0,
#   'One-Skillet Lemon Orzo Risotto': 4.0,
#   'Roasted Chicken with Patatas Bravas': 3.0,
#   'Seasonal Fruit Basket': 4.0,
#   'Steak au Poivre': 2.0,
#   'Strawberry Cheesecake Smoothie': 3.0},
#  'U1054': {'BBQ Shrimp Pizza': 5.0,
#   'Broccoli Parmesan Risotto': 5.0,
#   'Chicken Kiev': 2.0,
#   'Chicken Risotto Casserole': 4.0,
#   'Crispy Honey-Soy Barramundi': 4.0,
#   'Korean Pork Medallions': 5.0,
#   'Neapolitan Pizza Margherita': 3.0,
#   'New England-Style Fish Cakes': 4.0,
#   'Roasted Chicken with Patatas Bravas': 3.0,
#   'Seasonal Fruit Basket': 5.0,
#   'Thai Turkey Lettuce Wraps': 3.0},
#  'U1055': {'BBQ-Rubbed Crispy Chicken': 5.0,
#   'Buffalo Turkey Meatball Salad': 5.0,
#   'Chicken and Roasted Beet Salad': 5.0,
#   'Chocolate Strawberry Coconut Smoothie': 5.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 5.0,
#   'Korean Pork Medallions': 5.0,
#   'Spring Fruit Basket': 5.0,
#   'Strawberry Cheesecake Smoothie': 5.0,
#   'Thai Turkey Lettuce Wraps': 4.0},
#  'U1056': {'Acapulco Beef Burger': 5.0,
#   'BBQ-Rubbed Crispy Chicken': 5.0,
#   'Chicken Risotto Casserole': 5.0,
#   'Mango Tango Smoothie ': 5.0,
#   'Marsala Mushroom Gemelli Bake': 5.0,
#   'One-Skillet Lemon Orzo Risotto': 5.0,
#   'Roasted Chicken with Patatas Bravas': 5.0,
#   'Steak au Poivre': 5.0,
#   'Thai Fish Curry': 0.0,
#   'Thai Turkey Lettuce Wraps': 5.0},
#  'U1057': {'Argentine Shrimp Chimichurri': 2.0,
#   'BBQ-Rubbed Crispy Chicken': 2.0,
#   'Basil-Pecorino Campanelle': 1.0,
#   'Fiesta Chicken': 2.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 2.0,
#   'Pork Shumai Meatballs': 1.0,
#   'Skinny Chicken Bruschetta': 1.0,
#   'Strawberry Colada Smoothie': 2.0,
#   'Sun-Dried Tomato Pesto Spaghetti': 2.0,
#   'Tandoori-Rubbed Chicken': 2.0},
#  'U1058': {'Crispy Tofu with Chimichurri Aioli': 3.0,
#   'Fontina and Caramelized Onion Flatbread': 4.0,
#   'Marsala Mushroom Gemelli Bake': 2.0,
#   'Roasted Chicken with Patatas Bravas': 5.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 3.0,
#   'Steak au Poivre': 5.0,
#   'Sun-Dried Tomato Pesto Spaghetti': 4.0,
#   'Thai Fish Curry': 1.0},
#  'U1059': {'Acapulco Beef Burger': 5.0,
#   'BBQ-Rubbed Crispy Chicken': 3.0,
#   'Buffalo Turkey Meatball Salad': 2.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 4.0,
#   'Skinny Chicken Bruschetta': 0.0,
#   'Strawberry Cheesecake Smoothie': 5.0,
#   'Strawberry Colada Smoothie': 5.0,
#   'Tandoori-Rubbed Chicken': 2.0},
#  'U1060': {'Chayote Squash Enchiladas Verdes': 4.0,
#   'Filet Mignon with Balsamic Onion Marmalada': 3.0},
#  'U1061': {'Asparagus Panzanella Primavera': 3.0,
#   'BBQ Shrimp Pizza': 5.0,
#   'BBQ-Rubbed Crispy Chicken': 3.0,
#   'Basil-Pecorino Campanelle': 3.0,
#   'Farmhouse Fried Chicken': 5.0,
#   'Fiesta Chicken': 3.0,
#   'Garlic-Studded Pork Tenderloin': 3.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 5.0,
#   'Pineapple Powwow Smoothie': 4.0,
#   'Pork Shumai Meatballs': 4.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 2.0,
#   'Spring Fruit Basket': 4.0,
#   'Strawberry Cheesecake Smoothie': 5.0},
#  'U1062': {'Acapulco Beef Burger': 0.0,
#   'BBQ-Rubbed Crispy Chicken': 0.0,
#   'Chicken Risotto Casserole': 0.0,
#   'Crispy Tofu with Chimichurri Aioli': 0.0,
#   'Fiesta Chicken': 0.0,
#   'Fontina and Caramelized Onion Flatbread': 0.0,
#   'Neapolitan Pizza Margherita': 0.0,
#   'New England-Style Fish Cakes': 0.0,
#   'Roasted Chicken with Patatas Bravas': 0.0},
#  'U1063': {'Pork Chop with Pine Nut & Parmesan Butter': 3.0},
#  'U1064': {'Baja Fish Tacos': 3.0,
#   'Chicken Risotto Casserole': 3.0,
#   'French Mustard-Thyme Butter Pork Chop': 3.0,
#   'Seasonal Fruit Basket': 2.0,
#   'Shrimp with Tiger Sauce': 1.0},
#  'U1067': {'Chayote Squash Enchiladas Verdes': 2.0,
#   'Pork Chop with Pine Nut & Parmesan Butter': 0.0,
#   'Swiss Fondue Burger': 4.0},
#  'U1068': {'Chayote Squash Enchiladas Verdes': 2.0,
#   'Filet Mignon with Balsamic Onion Marmalada': 0.0,
#   'Pork Chop with Pine Nut & Parmesan Butter': 3.0,
#   'Swiss Fondue Burger': 0.0},
#  'U1069': {'Argentine Shrimp Chimichurri': 0.0,
#   'Classic Veggie Lasagna ': 0.0,
#   'Coconut Jasmine Rice Bowl': 0.0,
#   'Shrimp with Tiger Sauce': 0.0},
#  'U1071': {'BBQ-Rubbed Crispy Chicken': 5.0,
#   'Baja Fish Tacos': 5.0,
#   'Broccoli Parmesan Risotto': 5.0,
#   'Buffalo Turkey Meatball Salad': 5.0,
#   'Chicken Kiev': 5.0,
#   'Chicken Risotto Casserole': 5.0,
#   'Crispy Honey-Soy Barramundi': 5.0,
#   'Fiesta Chicken': 2.0,
#   'Jalapeño Popper-Stuffed Pork Tenderloin': 4.0,
#   'Korean Pork Medallions': 5.0,
#   'Seasonal Fruit Basket': 4.0,
#   'Skinny Chicken Bruschetta': 5.0,
#   'Strawberry Colada Smoothie': 5.0},
#  'U1073': {'Chicken Risotto Casserole': 0.0,
#   'Fiesta Chicken': 0.0,
#   'Healthy Takeout Mongolian Beef': 0.0,
#   'Pork Shumai Meatballs': 0.0,
#   'Roasted Chicken with Patatas Bravas': 0.0,
#   'Seasonal Fruit Basket': 0.0,
#   'Shrimp Scampi': 0.0,
#   'Skinny Chicken Bruschetta': 0.0,
#   'Spring Fruit Basket': 0.0,
#   'Tandoori-Rubbed Chicken': 0.0},
#  'U1075': {'BBQ Shrimp Pizza': 2.0,
#   'Chicken Kiev': 2.0,
#   'Crispy Honey-Soy Barramundi': 3.0,
#   'Fiesta Chicken': 3.0,
#   'French Mustard-Thyme Butter Pork Chop': 3.0,
#   'Marsala Mushroom Gemelli Bake': 4.0,
#   'One-Skillet Lemon Orzo Risotto': 3.0,
#   'Roasted Chicken with Patatas Bravas': 2.0,
#   'Steak au Poivre': 3.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 2.0,
#   'Thai Fish Curry': 5.0,
#   'Thai Turkey Lettuce Wraps': 2.0},
#  'U1076': {'Baja Fish Tacos': 5.0,
#   'Crispy Honey-Soy Barramundi': 4.0,
#   'Mango Tango Smoothie ': 2.0,
#   'Neapolitan Pizza Margherita': 4.0},
#  'U1077': {'Acapulco Beef Burger': 5.0,
#   'BBQ-Rubbed Crispy Chicken': 5.0,
#   'Mango Tango Smoothie ': 2.0,
#   'Neapolitan Pizza Margherita': 4.0,
#   'Seasonal Fruit Basket': 4.0},
#  'U1078': {'BBQ Shrimp Pizza': 4.0,
#   'Chicken Risotto Casserole': 5.0,
#   'Chicken and Roasted Beet Salad': 5.0,
#   'Fiesta Chicken': 2.0,
#   'One-Skillet Lemon Orzo Risotto': 2.0,
#   'Seasonal Fruit Basket': 5.0},
#  'U1079': {'Steak Moutarde': 5.0, 'Teriyaki Veggie Bibimbap': 5.0},
#  'U1080': {'Chayote Squash Enchiladas Verdes': 2.0},
#  'U1081': {'Acapulco Beef Burger': 3.0,
#   'BBQ-Rubbed Crispy Chicken': 2.0,
#   'Buffalo Turkey Meatball Salad': 4.0,
#   'Chicken Kiev': 2.0,
#   'Chicken Risotto Casserole': 2.0,
#   'Crispy Honey-Soy Barramundi': 0.0,
#   'Mango Tango Smoothie ': 2.0,
#   'Shrimp with Tiger Sauce': 2.0,
#   'Steak au Poivre': 4.0,
#   'Strawberry Colada Smoothie': 2.0,
#   'Sun-Dried Tomato Pesto Spaghetti': 1.0},
#  'U1082': {'Chayote Squash Enchiladas Verdes': 0.0,
#   'Swiss Fondue Burger': 0.0},
#  'U1083': {'Basil-Pecorino Campanelle': 4.0,
#   'Italian Sausage Parma Rosa': 4.0,
#   'Pineapple Powwow Smoothie': 2.0,
#   'Spring Fruit Basket': 5.0},
#  'U1084': {'Acapulco Beef Burger': 5.0,
#   'Farmhouse Fried Chicken': 5.0,
#   'Italian Sausage Parma Rosa': 5.0,
#   'New England-Style Fish Cakes': 5.0,
#   'Pineapple Powwow Smoothie': 2.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 2.0,
#   'Skinny Chicken Bruschetta': 5.0,
#   'Strawberry Colada Smoothie': 5.0},
#  'U1085': {'BBQ-Rubbed Crispy Chicken': 5.0,
#   'Baja Fish Tacos': 0.0,
#   'Chicken Pot Pie Primavera': 4.0,
#   'Fontina and Caramelized Onion Flatbread': 3.0,
#   'One-Skillet Lemon Orzo Risotto': 5.0,
#   'Steak au Poivre': 5.0,
#   'Sun-Dried Tomato Pesto Spaghetti': 5.0,
#   'Thai Fish Curry': 5.0},
#  'U1086': {'Acapulco Beef Burger': 3.0,
#   'Asparagus Panzanella Primavera': 2.0,
#   'BBQ Shrimp Pizza': 5.0,
#   'Jalapeño Popper-Stuffed Pork Tenderloin': 2.0,
#   'New England-Style Fish Cakes': 5.0,
#   'Seasonal Fruit Basket': 2.0,
#   'Shrimp Scampi': 2.0},
#  'U1087': {'Filet Mignon with Balsamic Onion Marmalada': 3.0,
#   'Pork Chop with Pine Nut & Parmesan Butter': 3.0,
#   'Swiss Fondue Burger': 4.0},
#  'U1088': {'Al Pastor Pork Tacos': 5.0,
#   'Argentine Shrimp Chimichurri': 4.0,
#   'BBQ Shrimp Pizza': 5.0,
#   'Chicken Kiev': 5.0,
#   'Classic Veggie Lasagna ': 5.0,
#   'Coconut Jasmine Rice Bowl': 5.0,
#   'French Mustard-Thyme Butter Pork Chop': 4.0,
#   'Fuji Apple Salad with Everything Bagel Croutons': 0.0,
#   'One-Skillet Lemon Orzo Risotto': 4.0,
#   'Shrimp with Tiger Sauce': 4.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 3.0,
#   'Thai Turkey Lettuce Wraps': 4.0},
#  'U1089': {'Acapulco Beef Burger': 2.0,
#   'Asparagus Panzanella Primavera': 2.0,
#   'Buffalo Turkey Meatball Salad': 2.0,
#   'Farmhouse Fried Chicken': 2.0,
#   'Fiesta Chicken': 2.0,
#   'Fontina and Caramelized Onion Flatbread': 2.0,
#   'Grilled Sirloin Steak Salad ': 2.0,
#   'Italian Sausage Parma Rosa': 2.0,
#   'Neapolitan Pizza Margherita': 0.0,
#   'Piedmont Chicken Breast': 0.0,
#   'Shrimp Scampi': 2.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 2.0,
#   'Strawberry Cheesecake Smoothie': 2.0,
#   'Tandoori-Rubbed Chicken': 2.0},
#  'U1090': {'Acapulco Beef Burger': 5.0,
#   'Chicken Risotto Casserole': 5.0,
#   'Korean Pork Medallions': 5.0,
#   'Pork Shumai Meatballs': 5.0,
#   'Roasted Chicken with Patatas Bravas': 5.0,
#   'Skinny Chicken Bruschetta': 5.0,
#   'Spring Fruit Basket': 3.0,
#   'Thai Turkey Lettuce Wraps': 3.0},
#  'U1091': {'BBQ-Rubbed Crispy Chicken': 2.0,
#   'Garlic-Studded Pork Tenderloin': 2.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 5.0,
#   'Grilled Sirloin Steak Salad ': 4.0,
#   'Spring Fruit Basket': 5.0},
#  'U1092': {'Acapulco Beef Burger': 0.0,
#   'Basil-Pecorino Campanelle': 0.0,
#   'Fuji Apple Salad with Everything Bagel Croutons': 1.0,
#   'Korean Pork Medallions': 3.0,
#   'Pineapple Powwow Smoothie': 2.0,
#   'Spring Fruit Basket': 1.0},
#  'U1093': {'Chicken Chopped Salad': 5.0},
#  'U1094': {'Al Pastor Pork Tacos': 0.0,
#   'Argentine Shrimp Chimichurri': 1.0,
#   'Classic Veggie Lasagna ': 0.0,
#   'Coconut Jasmine Rice Bowl': 2.0,
#   'French Mustard-Thyme Butter Pork Chop': 1.0,
#   'Fuji Apple Salad with Everything Bagel Croutons': 1.0,
#   'Shrimp with Tiger Sauce': 1.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 1.0},
#  'U1095': {'Fontina and Caramelized Onion Flatbread': 4.0,
#   'Garlic-Studded Pork Tenderloin': 3.0,
#   'Italian Sausage Parma Rosa': 5.0,
#   'Pineapple Powwow Smoothie': 5.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 4.0,
#   'Tandoori-Rubbed Chicken': 2.0},
#  'U1096': {'Farmhouse Fried Chicken': 5.0,
#   'Garlic-Studded Pork Tenderloin': 2.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 3.0,
#   'Grilled Sirloin Steak Salad ': 5.0,
#   'Italian Sausage Parma Rosa': 3.0,
#   'Korean Pork Medallions': 5.0,
#   'Pineapple Powwow Smoothie': 3.0,
#   'Tandoori-Rubbed Chicken': 2.0},
#  'U1097': {'Asparagus Panzanella Primavera': 4.0,
#   'Crispy Tofu with Chimichurri Aioli': 5.0,
#   'Farmhouse Fried Chicken': 2.0,
#   'Garlic-Studded Pork Tenderloin': 2.0,
#   'Piedmont Chicken Breast': 2.0,
#   'Pork Shumai Meatballs': 2.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 3.0},
#  'U1098': {'Acapulco Beef Burger': 3.0,
#   'Asparagus Panzanella Primavera': 3.0,
#   'BBQ-Rubbed Crispy Chicken': 2.0,
#   'Basil-Pecorino Campanelle': 3.0,
#   'Broccoli Parmesan Risotto': 3.0,
#   'Chicken Kiev': 3.0,
#   'Neapolitan Pizza Margherita': 2.0,
#   'Piedmont Chicken Breast': 3.0,
#   'Seasonal Fruit Basket': 4.0,
#   'Skinny Chicken Bruschetta': 4.0},
#  'U1099': {'Baja Fish Tacos': 2.0,
#   'Broccoli Parmesan Risotto': 2.0,
#   'Fiesta Chicken': 5.0,
#   'Fontina and Caramelized Onion Flatbread': 3.0,
#   'Marsala Mushroom Gemelli Bake': 2.0,
#   'Neapolitan Pizza Margherita': 2.0,
#   'New England-Style Fish Cakes': 2.0,
#   'Seasonal Fruit Basket': 5.0,
#   'Steak au Poivre': 2.0,
#   'Sun-Dried Tomato Pesto Spaghetti': 5.0},
#  'U1100': {'Chicken Chopped Salad': 3.0,
#   'French Toast and Bacon Monte Cristo': 2.0,
#   'Teriyaki Veggie Bibimbap': 5.0},
#  'U1101': {'BBQ Shrimp Pizza': 0.0,
#   'Broccoli Parmesan Risotto': 2.0,
#   'Chicken Kiev': 4.0,
#   'Chicken Risotto Casserole': 3.0,
#   'Chicken and Roasted Beet Salad': 0.0,
#   'Crispy Honey-Soy Barramundi': 2.0,
#   'Mango Tango Smoothie ': 3.0,
#   'Neapolitan Pizza Margherita': 4.0,
#   'Thai Turkey Lettuce Wraps': 3.0},
#  'U1103': {'Chayote Squash Enchiladas Verdes': 5.0,
#   'Pork Chop with Pine Nut & Parmesan Butter': 2.0,
#   'Swiss Fondue Burger': 2.0},
#  'U1104': {'Acapulco Beef Burger': 4.0,
#   'BBQ Shrimp Pizza': 3.0,
#   'BBQ-Rubbed Crispy Chicken': 3.0,
#   'Chicken Kiev': 3.0,
#   'Chicken Risotto Casserole': 2.0,
#   'Chocolate Strawberry Coconut Smoothie': 3.0,
#   'Crispy Honey-Soy Barramundi': 1.0,
#   'Fiesta Chicken': 3.0,
#   'Korean Pork Medallions': 3.0,
#   'Roasted Chicken with Patatas Bravas': 3.0,
#   'Strawberry Colada Smoothie': 3.0},
#  'U1105': {'Al Pastor Pork Tacos': 0.0,
#   'Chicken Risotto Casserole': 0.0,
#   'Crispy Honey-Soy Barramundi': 0.0,
#   'French Mustard-Thyme Butter Pork Chop': 0.0,
#   'Shrimp with Tiger Sauce': 0.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 0.0},
#  'U1106': {'Acapulco Beef Burger': 5.0,
#   'BBQ Shrimp Pizza': 2.0,
#   'Baja Fish Tacos': 2.0,
#   'Broccoli Parmesan Risotto': 1.0,
#   'Buffalo Turkey Meatball Salad': 2.0,
#   'Chicken Kiev': 0.0,
#   'Chicken Risotto Casserole': 0.0,
#   'Chicken and Roasted Beet Salad': 0.0,
#   'Chocolate Strawberry Coconut Smoothie': 0.0,
#   'Crispy Honey-Soy Barramundi': 3.0,
#   'Fiesta Chicken': 3.0,
#   'Marsala Mushroom Gemelli Bake': 4.0,
#   'Piedmont Chicken Breast': 5.0,
#   'Roasted Chicken with Patatas Bravas': 4.0,
#   'Skinny Chicken Bruschetta': 5.0,
#   'Strawberry Cheesecake Smoothie': 4.0,
#   'Strawberry Colada Smoothie': 4.0,
#   'Tandoori-Rubbed Chicken': 5.0},
#  'U1107': {'Chayote Squash Enchiladas Verdes': 5.0},
#  'U1108': {'Acapulco Beef Burger': 3.0,
#   'Basil-Pecorino Campanelle': 3.0,
#   'Buffalo Turkey Meatball Salad': 2.0,
#   'Chicken Kiev': 4.0,
#   'Garlic-Studded Pork Tenderloin': 2.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 5.0,
#   'Pineapple Powwow Smoothie': 5.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 2.0,
#   'Spring Fruit Basket': 3.0},
#  'U1109': {'Acapulco Beef Burger': 5.0,
#   'BBQ-Rubbed Crispy Chicken': 5.0,
#   'Baja Fish Tacos': 5.0,
#   'Broccoli Parmesan Risotto': 2.0,
#   'Buffalo Turkey Meatball Salad': 5.0,
#   'Chicken Kiev': 5.0,
#   'Fontina and Caramelized Onion Flatbread': 2.0,
#   'Jalapeño Popper-Stuffed Pork Tenderloin': 5.0,
#   'Neapolitan Pizza Margherita': 5.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 5.0},
#  'U1110': {'French Toast and Bacon Monte Cristo': 3.0},
#  'U1111': {'Classic Veggie Lasagna ': 1.0,
#   'Coconut Jasmine Rice Bowl': 2.0,
#   'Fuji Apple Salad with Everything Bagel Croutons': 5.0},
#  'U1112': {'Asparagus Panzanella Primavera': 1.0,
#   'Basil-Pecorino Campanelle': 0.0,
#   'Chocolate Strawberry Coconut Smoothie': 0.0,
#   'Farmhouse Fried Chicken': 2.0,
#   'Fiesta Chicken': 1.0,
#   'Garlic-Studded Pork Tenderloin': 0.0,
#   'Piedmont Chicken Breast': 1.0,
#   'Pork Shumai Meatballs': 1.0,
#   'Roasted Chicken with Patatas Bravas': 1.0,
#   'Skinny Chicken Bruschetta': 2.0,
#   'Spring Fruit Basket': 1.0,
#   'Tandoori-Rubbed Chicken': 2.0},
#  'U1113': {'Acapulco Beef Burger': 3.0,
#   'Basil-Pecorino Campanelle': 4.0,
#   'Broccoli Parmesan Risotto': 1.0,
#   'Chicken Kiev': 0.0,
#   'French Mustard-Thyme Butter Pork Chop': 4.0,
#   'Neapolitan Pizza Margherita': 2.0,
#   'Piedmont Chicken Breast': 3.0},
#  'U1114': {'BBQ-Rubbed Crispy Chicken': 0.0,
#   'Crispy Tofu with Chimichurri Aioli': 0.0,
#   'Fiesta Chicken': 0.0,
#   'Fontina and Caramelized Onion Flatbread': 2.0,
#   'Healthy Takeout Mongolian Beef': 0.0,
#   'Italian Sausage Parma Rosa': 0.0,
#   'Pineapple Powwow Smoothie': 0.0,
#   'Shrimp Scampi': 0.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 0.0,
#   'Strawberry Cheesecake Smoothie': 0.0},
#  'U1115': {'Al Pastor Pork Tacos': 1.0,
#   'Argentine Shrimp Chimichurri': 2.0,
#   'Classic Veggie Lasagna ': 5.0,
#   'Coconut Jasmine Rice Bowl': 4.0,
#   'French Mustard-Thyme Butter Pork Chop': 5.0,
#   'Fuji Apple Salad with Everything Bagel Croutons': 5.0,
#   'Shrimp with Tiger Sauce': 2.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 5.0},
#  'U1116': {'Acapulco Beef Burger': 5.0,
#   'BBQ-Rubbed Crispy Chicken': 5.0,
#   'Chicken Pot Pie Primavera': 3.0,
#   'Chicken Risotto Casserole': 5.0,
#   'Chocolate Strawberry Coconut Smoothie': 5.0,
#   'Fiesta Chicken': 5.0,
#   'Korean Pork Medallions': 5.0,
#   'Mango Tango Smoothie ': 3.0,
#   'Neapolitan Pizza Margherita': 5.0,
#   'Seasonal Fruit Basket': 0.0,
#   'Strawberry Colada Smoothie': 4.0},
#  'U1118': {'French Toast and Bacon Monte Cristo': 2.0,
#   'Teriyaki Veggie Bibimbap': 0.0},
#  'U1119': {'French Toast and Bacon Monte Cristo': 0.0,
#   'Steak Moutarde': 5.0,
#   'Teriyaki Veggie Bibimbap': 5.0},
#  'U1120': {'Acapulco Beef Burger': 0.0,
#   'Chicken Kiev': 2.0,
#   'Farmhouse Fried Chicken': 2.0,
#   'French Mustard-Thyme Butter Pork Chop': 5.0,
#   'Neapolitan Pizza Margherita': 0.0,
#   'New England-Style Fish Cakes': 4.0},
#  'U1121': {'French Toast and Bacon Monte Cristo': 0.0},
#  'U1122': {'Acapulco Beef Burger': 4.0,
#   'Crispy Tofu with Chimichurri Aioli': 5.0,
#   'Fiesta Chicken': 3.0,
#   'Fontina and Caramelized Onion Flatbread': 5.0,
#   'Healthy Takeout Mongolian Beef': 5.0,
#   'Marsala Mushroom Gemelli Bake': 3.0,
#   'Neapolitan Pizza Margherita': 5.0,
#   'Piedmont Chicken Breast': 5.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 3.0,
#   'Strawberry Cheesecake Smoothie': 4.0,
#   'Strawberry Colada Smoothie': 3.0,
#   'Tandoori-Rubbed Chicken': 2.0},
#  'U1123': {'Chayote Squash Enchiladas Verdes': 3.0,
#   'Filet Mignon with Balsamic Onion Marmalada': 2.0,
#   'Pork Chop with Pine Nut & Parmesan Butter': 5.0},
#  'U1124': {'Al Pastor Pork Tacos': 2.0,
#   'Argentine Shrimp Chimichurri': 2.0,
#   'Chicken Kiev': 2.0,
#   'Coconut Jasmine Rice Bowl': 2.0,
#   'Crispy Honey-Soy Barramundi': 2.0,
#   'French Mustard-Thyme Butter Pork Chop': 2.0,
#   'Fuji Apple Salad with Everything Bagel Croutons': 2.0,
#   'One-Skillet Lemon Orzo Risotto': 2.0,
#   'Shrimp with Tiger Sauce': 2.0,
#   'Thai Fish Curry': 1.0},
#  'U1125': {'Baja Fish Tacos': 2.0,
#   'Chicken Kiev': 3.0,
#   'Jalapeño Popper-Stuffed Pork Tenderloin': 3.0,
#   'Marsala Mushroom Gemelli Bake': 2.0,
#   'Neapolitan Pizza Margherita': 4.0,
#   'One-Skillet Lemon Orzo Risotto': 2.0,
#   'Roasted Chicken with Patatas Bravas': 3.0,
#   'Seasonal Fruit Basket': 2.0,
#   'Steak au Poivre': 2.0,
#   'Sun-Dried Tomato Pesto Spaghetti': 3.0,
#   'Thai Fish Curry': 3.0},
#  'U1126': {'Al Pastor Pork Tacos': 3.0,
#   'BBQ Shrimp Pizza': 3.0,
#   'Chicken Risotto Casserole': 3.0,
#   'Chicken and Roasted Beet Salad': 5.0,
#   'Coconut Jasmine Rice Bowl': 4.0,
#   'French Mustard-Thyme Butter Pork Chop': 5.0,
#   'Neapolitan Pizza Margherita': 2.0,
#   'Shrimp with Tiger Sauce': 0.0,
#   'Steelhead Trout in Shallot-Butter Sauce': 0.0},
#  'U1127': {'Chicken Chopped Salad': 5.0,
#   'French Toast and Bacon Monte Cristo': 3.0},
#  'U1128': {'Asparagus Panzanella Primavera': 0.0,
#   'Crispy Tofu with Chimichurri Aioli': 0.0,
#   'Fontina and Caramelized Onion Flatbread': 0.0,
#   'Grilled Sirloin Steak Salad ': 0.0,
#   'Piedmont Chicken Breast': 0.0,
#   'Pork Shumai Meatballs': 0.0,
#   'Seasonal Fruit Basket': 0.0,
#   'Shrimp Scampi': 0.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 0.0,
#   'Tandoori-Rubbed Chicken': 0.0},
#  'U1131': {'Al Pastor Pork Tacos': 4.0, 'Classic Veggie Lasagna ': 1.0},
#  'U1132': {'Acapulco Beef Burger': 5.0,
#   'BBQ-Rubbed Crispy Chicken': 5.0,
#   'Buffalo Turkey Meatball Salad': 5.0,
#   'Chicken Kiev': 2.0,
#   'Chicken Risotto Casserole': 5.0,
#   'Korean Pork Medallions': 3.0,
#   'Mango Tango Smoothie ': 2.0,
#   'Neapolitan Pizza Margherita': 2.0,
#   'Roasted Chicken with Patatas Bravas': 3.0,
#   'Thai Turkey Lettuce Wraps': 2.0},
#  'U1133': {'French Toast and Bacon Monte Cristo': 5.0, 'Steak Moutarde': 5.0},
#  'U1134': {'Acapulco Beef Burger': 4.0,
#   'BBQ-Rubbed Crispy Chicken': 3.0,
#   'Basil-Pecorino Campanelle': 3.0,
#   'Chicken Pot Pie Primavera': 2.0,
#   'Chocolate Strawberry Coconut Smoothie': 2.0,
#   'Farmhouse Fried Chicken': 0.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 3.0,
#   'Healthy Takeout Mongolian Beef': 5.0,
#   'Piedmont Chicken Breast': 3.0,
#   'Spring Fruit Basket': 0.0,
#   'Strawberry Cheesecake Smoothie': 3.0,
#   'Tandoori-Rubbed Chicken': 5.0},
#  'U1135': {'Acapulco Beef Burger': 0.0,
#   'BBQ Shrimp Pizza': 0.0,
#   'BBQ-Rubbed Crispy Chicken': 0.0,
#   'Baja Fish Tacos': 0.0,
#   'Broccoli Parmesan Risotto': 0.0,
#   'Buffalo Turkey Meatball Salad': 0.0,
#   'Chicken Kiev': 0.0,
#   'Chicken Risotto Casserole': 0.0,
#   'Chicken and Roasted Beet Salad': 0.0,
#   'Fiesta Chicken': 0.0,
#   'Jalapeño Popper-Stuffed Pork Tenderloin': 0.0,
#   'New England-Style Fish Cakes': 0.0,
#   'Seasonal Fruit Basket': 0.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 0.0},
#  'U1136': {'Asparagus Panzanella Primavera': 5.0,
#   'Basil-Pecorino Campanelle': 5.0,
#   'Buffalo Turkey Meatball Salad': 5.0,
#   'Italian Sausage Parma Rosa': 2.0,
#   'Skinny Chicken Bruschetta': 5.0,
#   'Tandoori-Rubbed Chicken': 2.0},
#  'U1137': {'Acapulco Beef Burger': 4.0,
#   'BBQ-Rubbed Crispy Chicken': 4.0,
#   'Baja Fish Tacos': 5.0,
#   'Chicken Pot Pie Primavera': 3.0,
#   'Fiesta Chicken': 5.0,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad': 5.0,
#   'Pineapple Powwow Smoothie': 5.0,
#   'Roasted Chicken with Patatas Bravas': 5.0,
#   'Shrimp Scampi': 5.0,
#   'Sirloin Steak and Shishito Pepper Skewers': 3.0,
#   'Skinny Chicken Bruschetta': 5.0},
#  'U1138': {'Asparagus Panzanella Primavera': 4.0}}

# %% [markdown]
# I also need to rewrite the Euclidean distance function for the dictionary data structure

# %%
from math import sqrt

def sim_distance(prefs, person1, person2):
    si={}
    for item in prefs[person1]:
        if item in prefs[person2]:
            si[item] = 1
            
    if len(si) == 0: return 0
    
    sum_of_squares = sum([pow(prefs[person1][item]-prefs[person2][item],2) for item in si])
    
    return 1/(1+sqrt(sum_of_squares))

# %% [markdown]
# Now I'll write a function to get a ranked list of recommendations.

# %%
# Gets recommendations for a person by using a weighted average
# of every other user's rankings
def getRecommendations(prefs,userID,similarity=sim_distance, n=5):
    totals={}
    simSums={}
    for other in prefs:
        # don't compare me to myself
        if other==userID: continue
        sim=similarity(prefs,userID,other)

        # ignore scores of zero or lower
        if sim <= 0: continue
        for item in prefs[other]:

            # only score movies I haven't seen yet
            if item not in prefs[userID] or prefs[userID][item]==0:
                # Similarity * Score
                totals.setdefault(item,0)
                totals[item] += prefs[other][item]*sim
                # Sum of similarities
                simSums.setdefault(item,0)
                simSums[item]+=sim

    # Create the normalized list
    rankings=[(total/simSums[item],item) for item,total in totals.items(  )]

    # Return the sorted list
    rankings.sort()
    rankings.reverse()
    return rankings[:n]

# %%
getRecommendations(rating_dict,'U1025', n=10)
# Out:
# [(4.2316027367034543, 'Korean Pork Medallions'),
#  (3.942810114744542,
#   'Grilled Red Pepper, Roasted Fennel and Goat Cheese Salad'),
#  (3.8095238095238098, 'Marsala Mushroom Gemelli Bake'),
#  (3.5625, 'Grilled Sirloin Steak Salad '),
#  (3.5263157894736841, 'Thai Fish Curry'),
#  (3.4630193016579667, 'One-Skillet Lemon Orzo Risotto'),
#  (3.3250691052501495, 'French Mustard-Thyme Butter Pork Chop'),
#  (3.318956467231482, 'Steak au Poivre'),
#  (3.2899375914569067, 'Farmhouse Fried Chicken'),
#  (3.2601342338692798, 'Chicken Pot Pie Primavera')]

# %% [markdown]
# And now we have a way to suggest the user which meals they might like to try next. The higher the score, more likely we believe they will rate the meal highly. Since the data came from another dataset, the meals don't necessarily make sense with what the user previously rated. However, with the actual user data, we would be able to predict preferences that would make more sense.
